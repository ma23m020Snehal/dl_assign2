jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/51159cbc851a3faae7945f0d2c5a84fa.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/8d8950fb91bb580d01bd5b43ad91c9c1.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/fa6bacc9942375978a708567c7259e58.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/901d9f06d9dc2300b82aa7f4cc1a98aa.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/eadd2c440a6939878872697095138c1c.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/abac95e0c3fb6e035bc0fa9629c1bdf1.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/c905121188800ae010ee61d57753fc68.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/77d90041a42013f06912b66b8f0b628f.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/a0cc7e7131b2052932d3b59029d13972.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/172ba3326607549b1db8f68f38297d79.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/1d5932d4f0aa2a425d149b83f7533ec5.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/970e6cf8a9a07c1422a95cebf0b7f776.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/6592cde5ba4831eb06756e6129bc44e3.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/a516b24ba9bd6ed231c8d88b6e21f5a4.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/a0e33fab2d9b166043cacbfa1da4e219.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/c434316152deddaab7db83fd085da878.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/f8cc88814c366aa2dfacc0543aed1cde.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/4a88f059fce5392ea42fe97477ab18e5.jpg
# /kaggle/input/mydata/inaturalist_12K/train/Mammalia/95bc60122ed7fd379dac958cf3cfa6a2.jpg

# %% [markdown]
# # Step 1 : Setting up wandb

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb")

# %%
import wandb
wandb.login(key=secret_value_0)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ma23m020 (snehalma23m020-iit-madras). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Step 2: Loading the inaturalist dataset
# # train set is divided into train and validation in the ratio 80-20.

# %%
train = '/kaggle/input/mydata/inaturalist_12K/train'
test = '/kaggle/input/mydata/inaturalist_12K/val'

# %%
classes = ['Amphibia','Animalia','Arachnida','Aves','Fungi','Insecta','Mammalia','Mollusca','Plantae','Reptilia']

# %% [markdown]
# # Step 3 : Importing the iportant libraries

# %%
import torch     # core package
import torch.nn as nn    # to build neural network 
import torch.optim as optim  # contains optimisers
#import pytorch_lightning as pl # manage devices 
import torch.nn.functional as F
import wandb
import random
from collections import defaultdict
from pytorch_lightning.loggers import WandbLogger
from torch.utils.data import DataLoader, random_split,Subset
from torchvision import transforms, datasets
#from pytorch_lightning.loggers import WandbLogger
#import pytorch_lightning as pl

# %% [markdown]
# Reference : [https://www.datacamp.com/tutorial/pytorch-lightning-tutorial](http://)

# %% [markdown]
# # Question 1:

# %% [markdown]
# # Step 4 : Set up

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')    # To check if GPU is available

# %% [markdown]
# # Step 5 : Building a CNN network

# %%
# function to compute image size after convolution
def compute_img_size(img_w, filter_size, padding, stride):
    return (1 + (img_w - filter_size + (2 * padding)) / stride)

# %%
# Reference: https://machinelearningmastery.com/building-a-convolutional-neural-network-in-pytorch/

class AdaptiveCNN(nn.Module):
    def __init__(self, input_size=224, input_channels=3, batch_size=64,num_filters=32, filter_org='same', kernel_size=[3]*5, act_fn='relu',num_neurons=256, batch_norm=True, dropout_rate=0.3,
                 learning_rate=1e-3, l2_reg=0.0):
        
        super(AdaptiveCNN, self).__init__()

        # hyperparameters
        self.batch_norm = batch_norm
        self.learning_rate = learning_rate
        self.l2_reg = l2_reg
        self.batch_size = batch_size

        # Set number of filters based on organization type
        if filter_org == 'same':   # keeping all the filters same
            filters = [num_filters] * 5
            
        elif filter_org == 'double': # doubling the filter size 
            filters = [num_filters, num_filters * 2, num_filters * 4, num_filters * 8, num_filters * 16]
        
        elif filter_org == 'half':  # halfing the filter size 
            filters = [num_filters, max(num_filters // 2, 1), max(num_filters // 4, 1), max(num_filters // 8, 1), max(num_filters // 16, 1)]
        
        else:
            raise ValueError("Invalid filter_org")

         # Mapping string for activation function
        act_func = {'relu': nn.ReLU(), 'tanh': nn.Tanh(), 'gelu': nn.GELU(), 'silu': nn.SiLU(), 'mish': nn.Mish()}
        activation = act_func[act_fn]

         # padding to keep output size constant (same padding)
        padding_vals = [k // 2 for k in kernel_size]

        # 5 convolutional blocks (using Sequential)
        # Every block: Conv2d → (Optional BatchNorm) → Activation → Dropout → MaxPool
        self.conv_layers = nn.Sequential(
            nn.Conv2d(input_channels, filters[0], kernel_size=kernel_size[0], padding=padding_vals[0]),
            nn.BatchNorm2d(filters[0]) if batch_norm else nn.Identity(),
            activation,
            nn.Dropout(p=dropout_rate),
            nn.MaxPool2d(2),

            nn.Conv2d(filters[0], filters[1], kernel_size=kernel_size[1], padding=padding_vals[1]),
            nn.BatchNorm2d(filters[1]) if batch_norm else nn.Identity(),
            activation,
            nn.Dropout(p=dropout_rate),
            nn.MaxPool2d(2),

            nn.Conv2d(filters[1], filters[2], kernel_size=kernel_size[2], padding=padding_vals[2]),
            nn.BatchNorm2d(filters[2]) if batch_norm else nn.Identity(),
            activation,
            nn.Dropout(p=dropout_rate),
            nn.MaxPool2d(2),

            nn.Conv2d(filters[2], filters[3], kernel_size=kernel_size[3], padding=padding_vals[3]),
            nn.BatchNorm2d(filters[3]) if batch_norm else nn.Identity(),
            activation,
            nn.Dropout(p=dropout_rate),
            nn.MaxPool2d(2),

            nn.Conv2d(filters[3], filters[4], kernel_size=kernel_size[4], padding=padding_vals[4]),
            nn.BatchNorm2d(filters[4]) if batch_norm else nn.Identity(),
            activation,
            nn.Dropout(p=dropout_rate),
            nn.MaxPool2d(2),
        )


        
        size = input_size
        for i in range(5):
            size = compute_img_size(size, kernel_size[i], padding_vals[i], 1)
            size = size // 2 # for pooling

         # Defining fully connected layers
        self.flattened_size = int(size * size * filters[4])

        self.fc_layers = nn.Sequential(
            
            nn.Flatten(),           # flattening of 3D tensor to 1D
            nn.Linear(self.flattened_size, num_neurons),
            activation,              # Activation function
            nn.Dropout(p=dropout_rate),   # Dropout (as regularization)
            nn.Linear(num_neurons, 10)    # Final output layer (for 10 classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)  # Forward pass through conv blocks
        x = self.fc_layers(x)     # Forward pass through fully connected blocks
        return x

# %% [markdown]
# # You can change the value of which ever parameter you want

# %%
# Example instantiation:
model = AdaptiveCNN(
    input_size=224,
    input_channels=3,
    num_filters=64,
    filter_org='double',
    kernel_size=[3, 5, 3, 3, 3],
    act_fn='gelu',
    num_neurons=512
)

# %% [markdown]
# # Q2

# %% [markdown]
# # Step 6 : Splitting the training dataset into train set and validation set

# %%
# Stratified split to ensure that each class is equally represented
def stratified_split(dataset, val_fraction=0.2, seed=42):
    
    random.seed(seed)   # Set seed for reproducibility
    
    # Create a dictionary mapping each class label to a list of its sample indices
    label_to_indices = defaultdict(list)

    
    for idx, (_, label) in enumerate(dataset.samples):
        label_to_indices[label].append(idx)

    train_indices, val_indices = [], []
    
    for label, indices in label_to_indices.items():
        n_val = int(len(indices) * val_fraction)
        random.shuffle(indices)
        val_indices.extend(indices[:n_val])
        train_indices.extend(indices[n_val:])
        
    return Subset(dataset, train_indices), Subset(dataset, val_indices)     # Return Subset objects to be used with DataLoader

# %% [markdown]
# # Step 7 : Loads the training dataset from the specified directory and return the stratified split

# %%
# Dataset loader with augmentation toggle
def load_datasets(data_dir, use_augmentation):

    # Base image transformations (always applied):
    base_transforms = [
        transforms.Resize((224, 224)),     # Resize images to 224x224 
        transforms.ToTensor(),     # Convert images to PyTorch tensors
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))     # Normalize images to [-1, 1] range using mean=0.5 and std=0.5 for all channels
    ]

    # Additional data augmentation techniques (optional):
    augment = [transforms.RandomHorizontalFlip(), transforms.RandomRotation(10)]

    # full transformation
    # If augmentation is enabled,apply augmentation transforms to base transforms
    transform = transforms.Compose(augment + base_transforms) if use_augmentation else transforms.Compose(base_transforms)

  # Load the entire dataset from the 'train' directory using ImageFolder structure
    full_dataset = datasets.ImageFolder(root=f"{data_dir}/train", transform=transform)
    
    return stratified_split(full_dataset)

# %% [markdown]
# # Step 8 : Sweep Configuration

# %%
sweep_config = {
    "method": "bayes",
    "name": "updated_bayes_sweep",
    "metric": {
         "name": "val_acc", 
         "goal": "maximize"
    },
    "parameters": {
        "num_filters": {
            "values": [32, 64, 128] 
        },
        "filter_org": {
            "values": ["same", "double", "half"]
        },
        "act_fn": {
            "values": ["relu", "gelu", "silu", "mish", "tanh"]  
        },
        "dropout_rate": {
            "values": [0, 0.2, 0.3, 0.5] 
        },
        "batch_norm": {
            "values": [True, False]
        },
        "data_augmentation": {
            "values": [True, False]
        },
        "num_neurons": {
            "values": [64, 128, 256]  
        },
        "learning_rate": {
            "values": [0.0005, 0.001, 0.0001] 
        },
        "batch_size": {
            "values": [32, 64]
        },
        "kernel_size": {
            "values": [
                [3]*5,
                [3, 5, 5, 7, 7],
                [5]*5,
                [7]*5,
                [7, 5, 5, 3, 3]
            ]
        },
        "l2_reg": {
            "values": [0, 0.0005, 0.05]
        },
        "epochs": {
            "values": [15,17,20]
        }
    }
}

# %% [markdown]
# # Step 9 :

# %%
def train():
    
    # Initialize a new W&B run
    wandb.init()

    # Access sweep configuration
    config = wandb.config

   # naming the run using key hyperparameters
    wandb.run.name = f"sweep_{config.act_fn}_{config.num_filters}_{config.filter_org}_{config.dropout_rate}"
    
  # Load dataset 
    trainset, valset = load_datasets("/kaggle/input/mydata/inaturalist_12K", config.data_augmentation)

 # data loaders for training and validation
    train_loader = DataLoader(trainset, batch_size=config.batch_size, shuffle=True)
    val_loader = DataLoader(valset, batch_size=config.batch_size, shuffle=False)

 # Initialize the AdaptiveCNN model using hyperparameters from wandb config
    model = AdaptiveCNN(
        input_size=224,
        input_channels=3,
        batch_size=config.batch_size,
        num_filters=config.num_filters,
        filter_org=config.filter_org,
        kernel_size=config.kernel_size,
        act_fn=config.act_fn,
        num_neurons=config.num_neurons,
        batch_norm=config.batch_norm,
        dropout_rate=config.dropout_rate,
        learning_rate=config.learning_rate,
        l2_reg=config.l2_reg
        
).to(device)


     # Define loss function (CrossEntropy for multi-class classification)
    criterion = nn.CrossEntropyLoss()

     # Define optimizer and include L2 regularization (weight decay)
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate, weight_decay=config.l2_reg)

    # Learning rate scheduler 
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

    
    # Training loop
    for epoch in range(config.epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            outputs = model(x)
            loss = criterion(outputs, y)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * x.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == y).sum().item()
            total += y.size(0)

        train_loss = running_loss / total
        train_acc = correct / total

        
        # Validation loop
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                outputs = model(x)
                loss = criterion(outputs, y)

                val_loss += loss.item() * x.size(0)
                _, predicted = torch.max(outputs, 1)
                val_correct += (predicted == y).sum().item()
                val_total += y.size(0)

        val_loss /= val_total
        val_acc = val_correct / val_total

        # Step the scheduler based on validation loss
        scheduler.step(val_loss)

       # Log metrics to W&B for the current epoch
        wandb.log({
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'train_acc': train_acc,
            'val_loss': val_loss,
            'val_acc': val_acc
        })


if __name__ == "__main__":
    sweep_id = wandb.sweep(sweep_config, project="q2_assign2_exp7")

     # Start the sweep agent to run training with different hyperparameters
    wandb.agent(sweep_id, function=train, project="q2_assign2_exp7", count=30)
# Out:
# wandb: Agent Starting Run: edsabkzc with config:
# wandb: 	act_fn: tanh
# wandb: 	batch_norm: True
# wandb: 	batch_size: 32
# wandb: 	data_augmentation: False
# wandb: 	dropout_rate: 0.5
# wandb: 	epochs: 17
# wandb: 	filter_org: double
# wandb: 	kernel_size: [5, 5, 5, 5, 5]
# wandb: 	l2_reg: 0.05
# wandb: 	learning_rate: 0.0005
# wandb: 	num_filters: 64
# wandb: 	num_neurons: 256
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_114654-edsabkzc</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/edsabkzc' target="_blank">laced-sweep-22</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/edsabkzc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/edsabkzc</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>train_acc</td><td>▁▂▂▃▂▃▅▆▆▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▃▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▂▂▃▃▃▃█▅▅▆▁▆█▄▅▅▇</td></tr><tr><td>val_loss</td><td>█▅▅▄▅▆▃▃▇▂▆▃▁▃▃▄▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>17</td></tr><tr><td>train_acc</td><td>0.18188</td></tr><tr><td>train_loss</td><td>2.19977</td></tr><tr><td>val_acc</td><td>0.14957</td></tr><tr><td>val_loss</td><td>2.27431</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_tanh_64_double_0.5</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/edsabkzc' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/edsabkzc</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_114654-edsabkzc/logs</code>
# wandb: Agent Starting Run: ezzn6ifv with config:
# wandb: 	act_fn: silu
# wandb: 	batch_norm: True
# wandb: 	batch_size: 64
# wandb: 	data_augmentation: False
# wandb: 	dropout_rate: 0
# wandb: 	epochs: 20
# wandb: 	filter_org: double
# wandb: 	kernel_size: [7, 7, 7, 7, 7]
# wandb: 	l2_reg: 0.05
# wandb: 	learning_rate: 0.0001
# wandb: 	num_filters: 64
# wandb: 	num_neurons: 128
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_124621-ezzn6ifv</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/ezzn6ifv' target="_blank">trim-sweep-23</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/ezzn6ifv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/ezzn6ifv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▂▂▃▃▃▃▃▃▃▄▅▆▆▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▆▆▆▆▅▄▃▃▃▃▂▂▁▁</td></tr><tr><td>val_acc</td><td>▁▂▃▂▃▄▃▄▃▃▁▆▆▇▇▇▇███</td></tr><tr><td>val_loss</td><td>▆▆▅▇▅▆▅▆▆▆█▂▂▂▁▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_acc</td><td>0.53512</td></tr><tr><td>train_loss</td><td>1.3513</td></tr><tr><td>val_acc</td><td>0.4032</td></tr><tr><td>val_loss</td><td>1.73923</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_silu_64_double_0</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/ezzn6ifv' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/ezzn6ifv</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_124621-ezzn6ifv/logs</code>
# wandb: Agent Starting Run: 22yl5o0f with config:
# wandb: 	act_fn: relu
# wandb: 	batch_norm: False
# wandb: 	batch_size: 64
# wandb: 	data_augmentation: False
# wandb: 	dropout_rate: 0.2
# wandb: 	epochs: 20
# wandb: 	filter_org: double
# wandb: 	kernel_size: [3, 3, 3, 3, 3]
# wandb: 	l2_reg: 0.0005
# wandb: 	learning_rate: 0.001
# wandb: 	num_filters: 64
# wandb: 	num_neurons: 256
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_141739-22yl5o0f</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/22yl5o0f' target="_blank">driven-sweep-24</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/22yl5o0f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/22yl5o0f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▂▂▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>train_loss</td><td>█▇▇▇▆▆▆▅▅▅▅▄▄▄▃▃▃▂▁▁</td></tr><tr><td>val_acc</td><td>▁▂▄▅▅▅▆█▅▅▇█▇▇▇▇█▇▆▇</td></tr><tr><td>val_loss</td><td>█▇▆▆▅▅▄▂▄▄▂▁▂▃▁▂▁▁▂▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_acc</td><td>0.58262</td></tr><tr><td>train_loss</td><td>1.17629</td></tr><tr><td>val_acc</td><td>0.31766</td></tr><tr><td>val_loss</td><td>1.99316</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_relu_64_double_0.2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/22yl5o0f' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/22yl5o0f</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_141739-22yl5o0f/logs</code>
# wandb: Agent Starting Run: 5empa7f2 with config:
# wandb: 	act_fn: mish
# wandb: 	batch_norm: True
# wandb: 	batch_size: 32
# wandb: 	data_augmentation: False
# wandb: 	dropout_rate: 0.3
# wandb: 	epochs: 17
# wandb: 	filter_org: same
# wandb: 	kernel_size: [7, 7, 7, 7, 7]
# wandb: 	l2_reg: 0.05
# wandb: 	learning_rate: 0.0005
# wandb: 	num_filters: 128
# wandb: 	num_neurons: 128
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_150711-5empa7f2</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/5empa7f2' target="_blank">logical-sweep-25</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/5empa7f2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/5empa7f2</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>train_acc</td><td>▁▂▄▅▅▆▅▅▄▅▅▅▇▇▇█▇</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▄▃▃▄▄▄▃▂▂▁▁▁</td></tr><tr><td>val_acc</td><td>▅▁▇▄▁█▅█▅▅▇▃▇▇█▆▅</td></tr><tr><td>val_loss</td><td>▅█▂▅█▁▅▂▄▃▄▅▃▃▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>17</td></tr><tr><td>train_acc</td><td>0.19812</td></tr><tr><td>train_loss</td><td>2.17183</td></tr><tr><td>val_acc</td><td>0.15108</td></tr><tr><td>val_loss</td><td>2.22484</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_mish_128_same_0.3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/5empa7f2' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/5empa7f2</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_150711-5empa7f2/logs</code>
# wandb: Agent Starting Run: 3dsc9e6r with config:
# wandb: 	act_fn: gelu
# wandb: 	batch_norm: True
# wandb: 	batch_size: 32
# wandb: 	data_augmentation: True
# wandb: 	dropout_rate: 0.2
# wandb: 	epochs: 15
# wandb: 	filter_org: half
# wandb: 	kernel_size: [5, 5, 5, 5, 5]
# wandb: 	l2_reg: 0.0005
# wandb: 	learning_rate: 0.001
# wandb: 	num_filters: 64
# wandb: 	num_neurons: 128
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_161836-3dsc9e6r</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/3dsc9e6r' target="_blank">peachy-sweep-26</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/3dsc9e6r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/3dsc9e6r</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▃▄▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▆▅▄▄▃▃▃▂▂▂▂▂▁</td></tr><tr><td>val_acc</td><td>▁▁▃▆▄▅▅▇▆▆▆▇▅▆█</td></tr><tr><td>val_loss</td><td>█▇▆▄▅▅▄▃▃▃▃▃▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_acc</td><td>0.38038</td></tr><tr><td>train_loss</td><td>1.76034</td></tr><tr><td>val_acc</td><td>0.31566</td></tr><tr><td>val_loss</td><td>1.9361</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_gelu_64_half_0.2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/3dsc9e6r' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/3dsc9e6r</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_161836-3dsc9e6r/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: t37pp2ih with config:
# wandb: 	act_fn: silu
# wandb: 	batch_norm: False
# wandb: 	batch_size: 32
# wandb: 	data_augmentation: True
# wandb: 	dropout_rate: 0.3
# wandb: 	epochs: 17
# wandb: 	filter_org: same
# wandb: 	kernel_size: [7, 5, 5, 3, 3]
# wandb: 	l2_reg: 0.05
# wandb: 	learning_rate: 0.0005
# wandb: 	num_filters: 32
# wandb: 	num_neurons: 128
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_165545-t37pp2ih</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/t37pp2ih' target="_blank">dazzling-sweep-27</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/t37pp2ih' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/t37pp2ih</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>train_acc</td><td>█▅█▇▇▅▃▆▃▁▃▆▅▆███</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>17</td></tr><tr><td>train_acc</td><td>0.1</td></tr><tr><td>train_loss</td><td>2.30259</td></tr><tr><td>val_acc</td><td>0.10005</td></tr><tr><td>val_loss</td><td>2.30259</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_silu_32_same_0.3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/t37pp2ih' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/t37pp2ih</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_165545-t37pp2ih/logs</code>
# wandb: Agent Starting Run: 69h0pv9s with config:
# wandb: 	act_fn: relu
# wandb: 	batch_norm: True
# wandb: 	batch_size: 64
# wandb: 	data_augmentation: True
# wandb: 	dropout_rate: 0.3
# wandb: 	epochs: 15
# wandb: 	filter_org: half
# wandb: 	kernel_size: [7, 7, 7, 7, 7]
# wandb: 	l2_reg: 0
# wandb: 	learning_rate: 0.0005
# wandb: 	num_filters: 64
# wandb: 	num_neurons: 128
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_173611-69h0pv9s</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/69h0pv9s' target="_blank">cosmic-sweep-28</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/69h0pv9s' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/69h0pv9s</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▃▄▄▅▅▆▆▆▇█▇▇██</td></tr><tr><td>train_loss</td><td>█▇▆▅▅▄▄▃▃▂▂▁▁▁▁</td></tr><tr><td>val_acc</td><td>▃▆█▆▅▅▃▁▂▃▃▃▃▃▃</td></tr><tr><td>val_loss</td><td>▆▂▁▃▂▂▅█▆▅▇▆███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_acc</td><td>0.355</td></tr><tr><td>train_loss</td><td>1.80718</td></tr><tr><td>val_acc</td><td>0.14007</td></tr><tr><td>val_loss</td><td>2.28754</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_relu_64_half_0.3</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/69h0pv9s' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/69h0pv9s</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_173611-69h0pv9s/logs</code>
# wandb: Agent Starting Run: jq1yvu2p with config:
# wandb: 	act_fn: silu
# wandb: 	batch_norm: False
# wandb: 	batch_size: 64
# wandb: 	data_augmentation: True
# wandb: 	dropout_rate: 0.2
# wandb: 	epochs: 15
# wandb: 	filter_org: double
# wandb: 	kernel_size: [7, 7, 7, 7, 7]
# wandb: 	l2_reg: 0
# wandb: 	learning_rate: 0.0005
# wandb: 	num_filters: 32
# wandb: 	num_neurons: 64
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_181429-jq1yvu2p</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/jq1yvu2p' target="_blank">lilac-sweep-29</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/jq1yvu2p' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/jq1yvu2p</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>train_acc</td><td>▁▂▃▃▄▄▅▅▅▆▆▆▇▇█</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▅▅▅▄▄▃▃▂▂▁</td></tr><tr><td>val_acc</td><td>▁▄▄▅▆▅▆▆▆▇▇▆▆▇█</td></tr><tr><td>val_loss</td><td>█▇▅▇▃▅▃▂▂▁▁▂▃▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>train_acc</td><td>0.464</td></tr><tr><td>train_loss</td><td>1.52434</td></tr><tr><td>val_acc</td><td>0.34817</td></tr><tr><td>val_loss</td><td>2.3977</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweep_silu_32_double_0.2</strong> at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/jq1yvu2p' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/jq1yvu2p</a><br> View project at: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250413_181429-jq1yvu2p/logs</code>
# wandb: Agent Starting Run: bv439qth with config:
# wandb: 	act_fn: relu
# wandb: 	batch_norm: False
# wandb: 	batch_size: 64
# wandb: 	data_augmentation: True
# wandb: 	dropout_rate: 0
# wandb: 	epochs: 17
# wandb: 	filter_org: half
# wandb: 	kernel_size: [7, 7, 7, 7, 7]
# wandb: 	l2_reg: 0.0005
# wandb: 	learning_rate: 0.001
# wandb: 	num_filters: 32
# wandb: 	num_neurons: 64
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250413_190053-bv439qth</code>
# Syncing run <strong><a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/bv439qth' target="_blank">distinctive-sweep-30</a></strong> to <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View project at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7</a>
#  View sweep at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/sweeps/c8axsvz5</a>
#  View run at <a href='https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/bv439qth' target="_blank">https://wandb.ai/snehalma23m020-iit-madras/q2_assign2_exp7/runs/bv439qth</a>
